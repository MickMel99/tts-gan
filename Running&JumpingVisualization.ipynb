# %% [markdown]
# ## Compare the similarities of the synthietic data with real data based on some evalutation matrices

# %% [markdown]
# ### Step 1: Load Real running and Jumping data

# %%
from LoadRealRunningJumping import *
from torch.utils import data

# %%
train_set = Running_Or_Jumping(incl_xyz_accel = True, incl_rms_accel = False, is_normalize = True, data_mode = 'Train')
# Out:
# Downloading UniMiB-SHAR.zip file
# data shape is (1200, 3, 1, 150), label shape is (1200, 1)
# Jumping label is 1, has 600 samples, Running label is 0, has 600 samples

# %%
real_data_loader = data.DataLoader(train_set, batch_size=1, num_workers=1, shuffle=True)

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
real_running = []
real_jumping = []

for i, (real_sig, label) in enumerate(real_data_loader):
    real_sig = real_sig.cpu().detach().numpy()
    sig = real_sig.reshape(real_sig.shape[1], real_sig.shape[3])
    if label[0] == 0:
        real_running.append(sig)
    elif label[0] == 1:
        real_jumping.append(sig)

real_running = np.array(real_running)
real_jumping = np.array(real_jumping)
print(real_running.shape)
print(real_jumping.shape)
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp310-cp310-win_amd64.whl (7.2 MB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\michael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\michael\appdata\roaming\python\python310\site-packages (from matplotlib) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp310-cp310-win_amd64.whl (55 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.0-cp310-cp310-win_amd64.whl (3.3 MB)
# Requirement already satisfied: numpy>=1.17 in c:\users\michael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.22.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\michael\appdata\roaming\python\python310\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\michael\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.2 matplotlib-3.5.2 pillow-9.1.0
# WARNING: You are using pip version 21.2.4; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\Michael\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# (600, 3, 150)
# (600, 3, 150)

# %%
fig, axs = plt.subplots(1, 10, figsize=(35,5))
fig.suptitle('Real_Running', fontsize=30)
for i in range(10):
    axs[i].plot(real_running[i][0][:])
    axs[i].plot(real_running[i][1][:])
    axs[i].plot(real_running[i][2][:])

# %%
fig, axs = plt.subplots(1, 10, figsize=(35,5))
fig.suptitle('Real_Jumping', fontsize=30)
for i in range(10):
    axs[i].plot(real_jumping[i][0][:])
    axs[i].plot(real_jumping[i][1][:])
    axs[i].plot(real_jumping[i][2][:])

# %% [markdown]
# ### Step 2: Load synthetic running and juumping data

# %%
from LoadSyntheticRunningJumping import *
from torch.utils import data

# %%
syn_data = Synthetic_Dataset()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 syn_data = Synthetic_Dataset()
#
# File c:\Users\Michael\Documents\Desktop\tts-gan-main\LoadSyntheticRunningJumping.py:21, in Synthetic_Dataset.__init__(self, Jumping_model_path, Running_model_path, sample_size)
#      19 #Generate Running Data
#      20 running_gen_net = Generator(seq_len=150, channels=3, latent_dim=100)
# ---> 21 running_ckp = torch.load(Running_model_path)
#      22 running_gen_net.load_state_dict(running_ckp['gen_state_dict'])
#      24 #Generate Jumping Data
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:712, in load(f, map_location, pickle_module, **pickle_load_args)
#     710             opened_file.seek(orig_position)
#     711             return torch.jit.load(opened_file)
# --> 712         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     713 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:1046, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1044 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1045 unpickler.persistent_load = persistent_load
# -> 1046 result = unpickler.load()
#    1048 torch._utils._validate_loaded_sparse_tensors()
#    1050 return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:1016, in _load.<locals>.persistent_load(saved_id)
#    1014 if key not in loaded_storages:
#    1015     nbytes = numel * torch._utils._element_size(dtype)
# -> 1016     load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1018 return loaded_storages[key]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:1001, in _load.<locals>.load_tensor(dtype, numel, key, location)
#     997 storage = zip_file.get_storage_from_record(name, numel, torch._UntypedStorage).storage()._untyped()
#     998 # TODO: Once we decide to break serialization FC, we can
#     999 # stop wrapping with _TypedStorage
#    1000 loaded_storages[key] = torch.storage._TypedStorage(
# -> 1001     wrap_storage=restore_location(storage, location),
#    1002     dtype=dtype)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:176, in default_restore_location(storage, location)
#     174 def default_restore_location(storage, location):
#     175     for _, _, fn in _package_registry:
# --> 176         result = fn(storage, location)
#     177         if result is not None:
#     178             return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:152, in _cuda_deserialize(obj, location)
#     150 def _cuda_deserialize(obj, location):
#     151     if location.startswith('cuda'):
# --> 152         device = validate_cuda_device(location)
#     153         if getattr(obj, "_torch_load_uninitialized", False):
#     154             storage_type = getattr(torch.cuda, type(obj).__name__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:136, in validate_cuda_device(location)
#     133 device = torch.cuda._utils._get_device_index(location, True)
#     135 if not torch.cuda.is_available():
# --> 136     raise RuntimeError('Attempting to deserialize object on a CUDA '
#     137                        'device but torch.cuda.is_available() is False. '
#     138                        'If you are running on a CPU-only machine, '
#     139                        'please use torch.load with map_location=torch.device(\'cpu\') '
#     140                        'to map your storages to the CPU.')
#     141 device_count = torch.cuda.device_count()
#     142 if device >= device_count:
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
syn_data_loader = data.DataLoader(syn_data, batch_size=1, num_workers=1, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 syn_data_loader = data.DataLoader(syn_data, batch_size=1, num_workers=1, shuffle=True)
#
# NameError: name 'syn_data' is not defined

# %%
import matplotlib.pyplot as plt
syn_running = []
syn_jumping = []

for i, (syn_sig, label) in enumerate(syn_data_loader):
    syn_sig = syn_sig.cpu().detach().numpy()
    sig = syn_sig.reshape(syn_sig.shape[1], syn_sig.shape[3])
    if label[0] == 0:
        syn_running.append(sig)
    elif label[0] == 1:
        syn_jumping.append(sig)

syn_running = np.array(syn_running)
syn_jumping = np.array(syn_jumping)
print(syn_running.shape)
print(syn_jumping.shape)
# Out:
# (1000, 3, 150)
# (1000, 3, 150)

# %%
fig, axs = plt.subplots(1, 10, figsize=(35,5))
fig.suptitle('Syn_Running', fontsize=30)
for i in range(10):
    axs[i].plot(syn_running[i][0][:])
    axs[i].plot(syn_running[i][1][:])
    axs[i].plot(syn_running[i][2][:])

# %%
fig, axs = plt.subplots(1, 10, figsize=(35,5))
fig.suptitle('Syn_Jumping', fontsize=30)
for i in range(10):
    axs[i].plot(syn_jumping[i][0][:])
    axs[i].plot(syn_jumping[i][1][:])
    axs[i].plot(syn_jumping[i][2][:])

# %% [markdown]
# ### Step 3: PCA

# %%
print(real_running.shape)
print(real_jumping.shape)
print(syn_running.shape)
print(syn_jumping.shape)
# Out:
# (600, 3, 150)
# (600, 3, 150)
# (1000, 3, 150)
# (1000, 3, 150)

# %%
real_running = np.transpose(real_running, (0, 2, 1))
real_jumping = np.transpose(real_jumping, (0, 2, 1))
syn_running = np.transpose(syn_running, (0, 2, 1))
syn_jumping = np.transpose(syn_jumping, (0, 2, 1))
print(real_running.shape)
print(real_jumping.shape)
print(syn_running.shape)
print(syn_jumping.shape)
# Out:
# (600, 150, 3)
# (600, 150, 3)
# (1000, 150, 3)
# (1000, 150, 3)

# %%
from visualizationMetrics import visualization

# %%
visualization(real_running, syn_running, 'pca', 'Running-pca')

# %%
#visualization(real_running, syn_jumping, 'pca')

# %%
visualization(real_jumping, syn_jumping, 'pca', 'Jumping-pca')

# %%
#visualization(real_jumping, syn_running, 'pca')

# %%
visualization(real_running, syn_running, 'tsne', 'Running-tsne')
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1200 samples in 0.000s...
# [t-SNE] Computed neighbors for 1200 samples in 0.085s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1200
# [t-SNE] Computed conditional probabilities for sample 1200 / 1200
# [t-SNE] Mean sigma: 2.310985
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.924973
# [t-SNE] KL divergence after 300 iterations: 1.496660

# %%
visualization(real_running, syn_jumping, 'tsne', 'Real-R_Syn_J-tsne')
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1200 samples in 0.000s...
# [t-SNE] Computed neighbors for 1200 samples in 0.042s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1200
# [t-SNE] Computed conditional probabilities for sample 1200 / 1200
# [t-SNE] Mean sigma: 2.333788
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.476753
# [t-SNE] KL divergence after 300 iterations: 1.357777

# %%
visualization(real_jumping, syn_jumping, 'tsne', 'Jumping-tsne')
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1200 samples in 0.000s...
# [t-SNE] Computed neighbors for 1200 samples in 0.036s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1200
# [t-SNE] Computed conditional probabilities for sample 1200 / 1200
# [t-SNE] Mean sigma: 2.187617
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.511246
# [t-SNE] KL divergence after 300 iterations: 1.745002

# %%
visualization(real_jumping, syn_running, 'tsne', 'Real-J_Syn_R-tsne')
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1200 samples in 0.001s...
# [t-SNE] Computed neighbors for 1200 samples in 0.053s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1200
# [t-SNE] Computed conditional probabilities for sample 1200 / 1200
# [t-SNE] Mean sigma: 2.382563
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.298691
# [t-SNE] KL divergence after 300 iterations: 1.805483
